# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager

# %%
import pandas as pd
from IPython.display import HTML
from IPython.core.display import display, HTML
import copy

# %%
meses = ["Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio",
           "Julio", "Agosto", "Septiembre", "Octubre", "Noviembre",
           "Diciembre"]
total=[1.41431e+08,2.92391e+07,1.6776e+08,1.54879e+08,5.52824e+07,9.90003e+07,4.26549e+07,7.00434e+07,1.47935e+07,1.28378e+08,1.13791e+08,8.45668e+07]

# %%
plt.figure(figsize=(30,10))
plt.plot(meses,total,'or')
#plt.plot(meses,elec,'*b')
plt.legend(["Total"], fontsize=20)
plt.xlabel("Meses" , fontsize=20 )
plt.ylabel("Flux" , fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)


plt.axvspan(0, 0.5, facecolor='white', alpha=0.5)
plt.axvspan(0.5, 1.5, facecolor='linen', alpha=0.5)
plt.axvspan(1.5, 2.5, facecolor='white', alpha=0.5)
plt.axvspan(2.5, 3.5, facecolor='linen', alpha=0.5)
plt.axvspan(3.5, 4.5, facecolor='white', alpha=0.5)
plt.axvspan(4.5, 5.5, facecolor='linen', alpha=0.5)
plt.axvspan(5.5, 6.5, facecolor='white', alpha=0.5)
plt.axvspan(6.5, 7.5, facecolor='linen', alpha=0.5)
plt.axvspan(7.5, 8.5, facecolor='white', alpha=0.5)
plt.axvspan(8.5, 9.5, facecolor='linen', alpha=0.5)
plt.axvspan(9.5, 10.5, facecolor='white', alpha=0.5)
plt.axvspan(10.5, 11.5, facecolor='linen', alpha=0.5)


plt.savefig('flujo_mensual.pdf')
plt.savefig('flujo_mensual.png', format='png', dpi=600)
plt.savefig('flujo_mensual.eps', format='eps', dpi=600)



plt.show
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...
